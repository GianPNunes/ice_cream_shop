# %%
import pandas as pd
import pathlib
import matplotlib.pyplot as plt
import numpy as np


DATA_BASE = pathlib.Path(r'base_dados.xlsx')

arq = pd.read_excel(DATA_BASE)
arq['total de vendas'] = arq['quant']*arq[r'preço\un'
display(arq)
# Out:
#       sabores  quant  preço\un  total de vendas
# 0         uva     34       3.0            102.0
# 1     morango     54       3.5            189.0
# 2       creme     13       2.5             32.5
# 3  napolitano     56       2.0            112.0
# 4        coco     53       2.6            137.8
# 5   chocolate     53       3.0            159.0

# %%
plt.plot_date( arq['sabores'].values, arq['total de vendas'].values)
